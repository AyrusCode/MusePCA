# %%
from muselsl import stream, list_muses, view, record
from multiprocessing import Process
from mne import Epochs, find_events
from time import time, strftime, gmtime
import os

from collections import OrderedDict
import warnings
warnings.filterwarnings('ignore')

from scipy.io import loadmat


from psychopy import prefs
#prefs.hardware['audioLib'] = ['PTB']
#prefs.hardware['audioLib'] = ['pyo'] # PTB']

from eegnb.experiments.auditory_oddball import PCAstimpres
from eegnb.analysis import utils

import numpy as np, pandas as pd
import h5py
import time
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#Data Collection for Training
duration = 200
duration2 = 9999
eegnb_data_dir = "C:\\Users\\surya\\Documents\\eegnote\\Data"
output_dir = os.path.join(eegnb_data_dir, "sp")

recording_path = os.path.join(output_dir, 
                              ("PCArecording_%s.csv" % strftime("%Y-%m-%d-%H.%M.%S", gmtime())))
print('Recording data to: ', recording_path)

present_kwargs = {'duration': duration2}


recording = Process(target=record, args=(duration, recording_path))

time.sleep(10)

#stimulus = Process(target=n170.present, args=(duration,))
stimulus = Process(target=PCAstimpres.present, kwargs=present_kwargs)#(duration,stim_types,itis))

#time.sleep(20) # added this to deal with issue of 'can't find markers stream' in subprocess message outputs

#recording = Process(target=record, args=(duration, recording_path))

stimulus.start()
recording.start()
# Out:
# Recording data to:  C:\Users\surya\Documents\eegnote\Data\sp\PCArecording_2020-06-26-16.09.46.csv

# %%
pd.read_csv(recording_path)
# Out:
#          timestamps     TP9     AF7     AF8     TP10  Right AUX  Marker0
# 0      1.593187e+09  54.688  24.902  30.273   68.359     78.613      0.0
# 1      1.593187e+09  78.125  26.855  25.879   95.215    240.234      0.0
# 2      1.593187e+09  14.648  29.297  28.320    3.418     57.129      0.0
# 3      1.593187e+09 -20.508  30.273  34.180  -35.156   -105.469      0.0
# 4      1.593187e+09  36.621  28.809  36.133   42.480     22.949      0.0
# ...             ...     ...     ...     ...      ...        ...      ...
# 51043  1.593188e+09  83.008  28.809  30.273   93.750    204.102      0.0
# 51044  1.593188e+09  17.090  30.273  32.227   -4.395    -28.809      0.0
# 51045  1.593188e+09 -19.531  27.832  30.762  -41.016   -150.879      0.0
# 51046  1.593188e+09  28.809  25.879  28.809   45.410     75.195      0.0
# 51047  1.593188e+09  78.125  30.273  31.738  101.562    253.418      0.0
#
# [51048 rows x 7 columns]

# %% [markdown]
# ## Load and plot the data

# %%
#raw = utils.load_data('visual/N170', sfreq=256., 
#                      subject_nb=subject, session_nb=session)

# %%
import glob

# %%
recordings_dir = os.path.split(recording_path)[0]
recordings_files = sorted(glob.glob(os.path.join(recordings_dir, '*.csv')))
recordings_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a12df203c22d> in <module>
# ----> 1 recordings_dir = os.path.split(recording_path)[0]
#       2 recordings_files = sorted(glob.glob(os.path.join(recordings_dir, '*.csv')))
#       3 recordings_files
#
# NameError: name 'recording_path' is not defined

# %%
raw = utils.load_muse_csv_as_raw(recordings_files, stim_ind=5)
#raw = utils.load_muse_csv_as_raw(recordings_files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1b233d215629> in <module>
# ----> 1 raw = utils.load_muse_csv_as_raw(recordings_files, stim_ind=5)
#       2 #raw = utils.load_muse_csv_as_raw(recordings_files)
#
# NameError: name 'recordings_files' is not defined

# %% [markdown]
# ### Visualizing the Power Spectrum
#
# Plotting the power spectral density (PSD) of our dataset will give us a glimpse at the different frequencies that are present. We won't be able to see the N170 in the PSD, but it will give us an impression of how noisy our data was. A very noisy or flat PSD may represent poor signal quality at certain electrodes

# %%
# %matplotlib inline
raw.plot_psd();
# Out:
# Effective window size : 8.000 (s)

# %% [markdown]
# ### Filtering
#
# Most ERP components are composed of lower frequency fluctuations in the EEG signal. Thus, we can filter out all frequencies between 1 and 30 hz in order to increase our ability to detect them.

# %%
raw.filter(1,30, method='iir')
raw.plot_psd(fmin=1, fmax=30);
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
# Using filter length: 51048
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# Effective window size : 8.000 (s)

# %% [markdown]
# ### Epoching

# %%
events = find_events(raw)
event_id = {'up': 1, 'nothing': 2}
# Out:
# 21 events found
# Event IDs: [1 2]

# %%
event_id
# Out:
# {'up': 1, 'nothing': 2}

# %%
events
# Out:
# array([[ 4770,     0,     1],
#        [ 7077,     0,     2],
#        [ 9383,     0,     2],
#        [11690,     0,     1],
#        [13997,     0,     2],
#        [16303,     0,     2],
#        [18610,     0,     2],
#        [20917,     0,     1],
#        [23224,     0,     1],
#        [25530,     0,     1],
#        [27837,     0,     2],
#        [30143,     0,     2],
#        [32450,     0,     2],
#        [34757,     0,     1],
#        [37064,     0,     2],
#        [39372,     0,     2],
#        [41678,     0,     2],
#        [43987,     0,     1],
#        [46294,     0,     1],
#        [48601,     0,     1],
#        [50908,     0,     2]], dtype=int64)

# %%
# Create an MNE Epochs object representing all the epochs around stimulus presentation
epochs = Epochs(raw, events=events, event_id=event_id, 
                tmin=-0.1, tmax=0.8, baseline=None,
                reject=None, preload=True, 
                verbose=False, picks=[0,1,2,3])
print('sample drop %: ', (1 - len(epochs.events)/len(events)) * 100)
epochs
tevents = np.transpose(events)
len(tevents)
len(events)
# Out:
# sample drop %:  4.761904761904767
# 21

# %%
epochs
# Out:
# <Epochs  |   20 events (all good), -0.101562 - 0.800781 sec, baseline off, ~162 kB, data loaded,
#  'nothing': 11
#  'up': 9>

# %%
# %matplotlib inline
conditions = OrderedDict()
conditions['Nothing'] = [2]
conditions['Up'] = [1]

fig, ax = utils.plot_conditions(epochs, conditions=conditions, 
                                ci=97.5, n_boot=1000, title='',
                                diff_waveform=(1, 2))
